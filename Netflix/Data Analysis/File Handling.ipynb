# %%
import os

# %%
print('Current Working Directly is :', os.getcwd())
# Out:
# Current Working Directly is : c:\Users\anamika\OneDrive\Desktop\first\Netflix\Data Analysis

# %%
files = os.listdir()
print('Files in current working directory',files)
# Out:
# Files in current working directory ['data analysis.ipynb', 'File Handling.ipynb', 'netflix_titles.csv']

# %%
files = os.listdir(r"C:\Users\anamika\OneDrive\Desktop\first")
print('Files in specified directory :',files)
print('Number of files in specified directory :',len (files))
# Out:
# Files in specified directory : ['.git', 'Calculator.py', 'Dashboard', 'Data Analysis', 'Data Structures', 'Netflix']
# Number of files in specified directory : 6

# %%
total_files = 0
for path, folder, files in os.walk(r"C:\Users\anamika\OneDrive\Desktop\first"):
    print('=>', path)
    print('📁', folder)
    print('🗄️',files)
    total_files +=len(files)
print('Total Files in directry tree :',total_files)
# Out:
# => C:\Users\anamika\OneDrive\Desktop\first
# 📁 ['.git', 'Dashboard', 'Data Analysis', 'Data Structures', 'Netflix']
# 🗄️ ['Calculator.py']
# => C:\Users\anamika\OneDrive\Desktop\first\.git
# 📁 ['hooks', 'info', 'logs', 'objects', 'refs']
# 🗄️ ['COMMIT_EDITMSG', 'config', 'description', 'FETCH_HEAD', 'HEAD', 'index']
# => C:\Users\anamika\OneDrive\Desktop\first\.git\hooks
# 📁 []
# 🗄️ ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'sendemail-validate.sample', 'update.sample']
# => C:\Users\anamika\OneDrive\Desktop\first\.git\info
# 📁 []
# 🗄️ ['exclude']
# => C:\Users\anamika\OneDrive\Desktop\first\.git\logs
# 📁 ['refs']
# 🗄️ ['HEAD']
# => C:\Users\anamika\OneDrive\Desktop\first\.git\logs\refs
# 📁 ['heads', 'remotes']
# 🗄️ []
# ...

# %%
Files = r"C:\Users\anamika\OneDrive\Desktop\first"
if os.path.exists(Files):
   print("The File exists")
else:
   print("The file dows not exists")
# Out:
# The File exists
